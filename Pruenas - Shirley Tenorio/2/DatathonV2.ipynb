# %%
# Importamos la Libreria de Pandas (Manejo de DataFrames)
import pandas as pd
# Importamos la libreria de Numpy para las operaciones numéricas
import numpy as np
# importamos el modelo RandomForestRefressor  
from sklearn.ensemble import RandomForestRegressor
# importamos métricas para calcular el error absoluto
from sklearn.metrics import mean_absolute_error
# Importamos el modelo de seleccion de datos para dividir
from sklearn.model_selection import train_test_split
# Importamos Imputer para el manejo de valores Faltantes
from sklearn.impute import SimpleImputer
# Importamos el modelo de machine learning: DecisionTreeRegressor
from sklearn.tree import DecisionTreeRegressor
# Importamos el modelo de machine learning: XGBRegressor
from xgboost import XGBRegressor
# Importamos el modelo de machine learning: SVM
from sklearn.svm import SVR
#from sklearn import svm

import textwrap

from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.gaussian_process.kernels import RBF
from sklearn.gaussian_process import GaussianProcessClassifier

from sklearn import linear_model
import time

# %%
def etiquetar_columnas(data, columnas_categoricas):
    lb=[]
    for columna in columnas_categoricas:
        l=LabelEncoder()
        lb.append(l.fit(list(data[columna].dropna())))
    
    return lb

def transformar_etiquetas(data, l, columnas_categoricas):
    i=0
    for columna in columnas_categoricas:
        data.loc[data[columna].notnull(),columna] = l[i].transform( data.loc[data[columna].notnull(), columna] )
        i=i+1

# Funcion para mostar cadenas en color
def printC(msg, type):
    if type=="err":
        print('\x1b[1;31m' + msg + '\x1b[0m')
    elif type=="succ":
        print('\x1b[1;32m' + msg + '\x1b[0m')
    elif type=="warn":
        print('\x1b[1;33m' + msg + '\x1b[0m')
    elif type=="prim":
        print('\x1b[1;34m' + msg + '\x1b[0m')
    else:
        print('\x1b[1;37m' + msg + '\x1b[0m')

# %% [markdown]
# ## 1. Importacion de set de datos

# %%
# Diccionario de datos
df_dictionary = pd.read_csv('Dictionary.csv')
# Modelos de estructura de datos para enviar la solución
df_samplesubmission = pd.read_csv('samplesubmission.csv')
# Identificadores de los item a ser probados
df_solution_template = pd.read_csv('solution_template.csv')
# Datos de entrenamiento
df_training_v2 = pd.read_csv('training_v2.csv')
# Datos de prueba
df_test_unlabeled = pd.read_csv('unlabeled.csv')

# %%
# Vista del Diccionario de datos
display( df_dictionary.head() )
print("\nTamano del diccionario de datos")
df_dictionary.shape
# Out:
#       Category  ... Example
# 0   identifier  ...    None
# 1   identifier  ...    None
# 2   identifier  ...    None
# 3  demographic  ...       0
# 4  demographic  ...    None
#
# [5 rows x 6 columns]
# Tamano del diccionario de datos
# (188, 6)

# %%
# Vista Modelo de estructura de datos para enviar la solución
display( df_samplesubmission.head() )
print("\nTamano del modelo de estructura")
df_samplesubmission.shape
# De ahora en adelante lo descartamos
# Out:
#    encounter_id  hospital_death
# 0             2           0.500
# 1             5           0.200
# 2             7           0.001
# Tamano del modelo de estructura
# (3, 2)

# %%
# Identificadores de los item a ser probados
display( df_solution_template.head() )
print("\nTamano de los items")
df_solution_template.shape
# Out:
#    encounter_id  hospital_death
# 0             2             NaN
# 1             5             NaN
# 2             7             NaN
# 3             8             NaN
# 4            10             NaN
# Tamano de los items
# (39308, 2)

# %%
# Vista previa de Datos de entrenamiento
display( df_training_v2.head() )
print("\nTamano de los Datos de entrenamiento")
display( df_training_v2.shape )
# Out:
#    encounter_id  patient_id  ...  apache_3j_bodysystem  apache_2_bodysystem
# 0         66154       25312  ...                Sepsis       Cardiovascular
# 1        114252       59342  ...           Respiratory          Respiratory
# 2        119783       50777  ...             Metabolic            Metabolic
# 3         79267       46918  ...        Cardiovascular       Cardiovascular
# 4         92056       34377  ...                Trauma               Trauma
#
# [5 rows x 186 columns]
# Tamano de los Datos de entrenamiento
# (91713, 186)

# %%
# Vista previa de Datos de prueba
display( df_test_unlabeled.head() )
print("\nTamano de los Datos de prueba")
df_test_unlabeled.shape
# Out:
#    encounter_id  patient_id  ...  apache_3j_bodysystem  apache_2_bodysystem
# 0             2      127112  ...          Neurological           Neurologic
# 1             5      130737  ...          Neurological           Neurologic
# 2             7      101458  ...        Cardiovascular       Cardiovascular
# 3             8       48067  ...           Respiratory          Respiratory
# 4            10       25865  ...          Neurological           Neurologic
#
# [5 rows x 186 columns]
# Tamano de los Datos de prueba
# (39308, 186)

# %% [markdown]
# ## 2. Exploration de tipos de columnas, informacion y describe

# %%
display( df_solution_template.info() )
print("**Los items de la solucion 2  (encounter_id  y hospital_death ).**")

print("\n\n**Los tipos de las columnas son:")
display( df_solution_template.dtypes )

print("\n\n**Describe:")
df_solution_template.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39308 entries, 0 to 39307
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   encounter_id    39308 non-null  int64
#  1   hospital_death  0 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 614.3 KB
# None
# **Los items de la solucion 2  (encounter_id  y hospital_death ).**
#
#
# **Los tipos de las columnas son:
# encounter_id        int64
# hospital_death    float64
# dtype: object
# **Describe:
#         encounter_id  hospital_death
# count   39308.000000             0.0
# mean    65346.396891             NaN
# std     37920.612047             NaN
# min         2.000000             NaN
# 25%     32568.500000             NaN
# 50%     65222.000000             NaN
# 75%     98174.500000             NaN
# max    131050.000000             NaN

# %%
display( df_training_v2.info() )
print("**Los datos de entrenamiento tienen 186 columnas ( 170=float64, 8=int64, 8=object ).**")

print("\n\n**Los tipos de las columnas son:")
display( df_training_v2.dtypes )

print("\n\n**Describe:")
display( df_training_v2.describe() )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91713 entries, 0 to 91712
# Columns: 186 entries, encounter_id to apache_2_bodysystem
# dtypes: float64(170), int64(8), object(8)
# memory usage: 130.1+ MB
# None
# **Los datos de entrenamiento tienen 186 columnas ( 170=float64, 8=int64, 8=object ).**
#
#
# **Los tipos de las columnas son:
# encounter_id                     int64
# patient_id                       int64
# hospital_id                      int64
# hospital_death                   int64
# age                            float64
#                                 ...
# leukemia                       float64
# lymphoma                       float64
# solid_tumor_with_metastasis    float64
# apache_3j_bodysystem            object
# apache_2_bodysystem             object
# Length: 186, dtype: object
# **Describe:
#         encounter_id     patient_id  ...      lymphoma  solid_tumor_with_metastasis
# count   91713.000000   91713.000000  ...  90998.000000                 90998.000000
# mean    65606.079280   65537.131464  ...      0.004132                     0.020638
# std     37795.088538   37811.252183  ...      0.064148                     0.142169
# min         1.000000       1.000000  ...      0.000000                     0.000000
# 25%     32852.000000   32830.000000  ...      0.000000                     0.000000
# 50%     65665.000000   65413.000000  ...      0.000000                     0.000000
# 75%     98342.000000   98298.000000  ...      0.000000                     0.000000
# max    131051.000000  131051.000000  ...      1.000000                     1.000000
#
# [8 rows x 178 columns]

# %%
display( df_test_unlabeled.info() )
print("**Los datos de prueba tienen 186 columnas ( 171=float64, 7=int64, 8=object ).**")

print("\n\n**Los tipos de las columnas son:")
display( df_test_unlabeled.dtypes )

print("\n\n**Describe:")
df_test_unlabeled.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39308 entries, 0 to 39307
# Columns: 186 entries, encounter_id to apache_2_bodysystem
# dtypes: float64(171), int64(7), object(8)
# memory usage: 55.8+ MB
# None
# **Los datos de prueba tienen 186 columnas ( 171=float64, 7=int64, 8=object ).**
#
#
# **Los tipos de las columnas son:
# encounter_id                     int64
# patient_id                       int64
# hospital_id                      int64
# hospital_death                 float64
# age                            float64
#                                 ...
# leukemia                       float64
# lymphoma                       float64
# solid_tumor_with_metastasis    float64
# apache_3j_bodysystem            object
# apache_2_bodysystem             object
# Length: 186, dtype: object
# **Describe:
#         encounter_id     patient_id  ...      lymphoma  solid_tumor_with_metastasis
# count   39308.000000   39308.000000  ...  39129.000000                 39129.000000
# mean    65346.396891   65504.743462  ...      0.004319                     0.021365
# std     37920.612047   37878.696746  ...      0.065578                     0.144600
# min         2.000000      11.000000  ...      0.000000                     0.000000
# 25%     32568.500000   32590.250000  ...      0.000000                     0.000000
# 50%     65222.000000   65753.500000  ...      0.000000                     0.000000
# 75%     98174.500000   98270.250000  ...      0.000000                     0.000000
# max    131050.000000  131050.000000  ...      1.000000                     1.000000
#
# [8 rows x 178 columns]

# %% [markdown]
# ## 3. Buscando valores nulos#

# %%
# Funcion para identificar columnas que tienen valores nulos
def mostrasColumnasConNulos(df):
  for i,c in enumerate( list(df.columns) ):
    nulos = df[c].isnull().sum()
    if nulos>0 :
      print(i, c, "Cantidad Nan: "+str( nulos ), "Cantidad de Unicos: " + str(df[c].unique().size ) )

# %%
mostrasColumnasConNulos( df_training_v2 )
print("\nExisten mucho valores nulos")
# Out:
# 4 age Cantidad Nan: 4228 Cantidad de Unicos: 75
# 5 bmi Cantidad Nan: 3429 Cantidad de Unicos: 34889
# 7 ethnicity Cantidad Nan: 1395 Cantidad de Unicos: 7
# 8 gender Cantidad Nan: 25 Cantidad de Unicos: 3
# 9 height Cantidad Nan: 1334 Cantidad de Unicos: 402
# 10 hospital_admit_source Cantidad Nan: 21409 Cantidad de Unicos: 16
# 11 icu_admit_source Cantidad Nan: 112 Cantidad de Unicos: 6
# 17 weight Cantidad Nan: 2720 Cantidad de Unicos: 3410
# 18 albumin_apache Cantidad Nan: 54379 Cantidad de Unicos: 36
# 19 apache_2_diagnosis Cantidad Nan: 1662 Cantidad de Unicos: 45
# 20 apache_3j_diagnosis Cantidad Nan: 1101 Cantidad de Unicos: 400
# 22 arf_apache Cantidad Nan: 715 Cantidad de Unicos: 3
# 23 bilirubin_apache Cantidad Nan: 58134 Cantidad de Unicos: 363
# 24 bun_apache Cantidad Nan: 19262 Cantidad de Unicos: 477
# 25 creatinine_apache Cantidad Nan: 18853 Cantidad de Unicos: 1128
# 26 fio2_apache Cantidad Nan: 70868 Cantidad de Unicos: 83
# 27 gcs_eyes_apache Cantidad Nan: 1901 Cantidad de Unicos: 5
# 28 gcs_motor_apache Cantidad Nan: 1901 Cantidad de Unicos: 7
# 29 gcs_unable_apache Cantidad Nan: 1037 Cantidad de Unicos: 3
# 30 gcs_verbal_apache Cantidad Nan: 1901 Cantidad de Unicos: 6
# 31 glucose_apache Cantidad Nan: 11036 Cantidad de Unicos: 566
# 32 heart_rate_apache Cantidad Nan: 878 Cantidad de Unicos: 150
# 33 hematocrit_apache Cantidad Nan: 19878 Cantidad de Unicos: 354
# 34 intubated_apache Cantidad Nan: 715 Cantidad de Unicos: 3
# 35 map_apache Cantidad Nan: 994 Cantidad de Unicos: 162
# 36 paco2_apache Cantidad Nan: 70868 Cantidad de Unicos: 705
# 37 paco2_for_ph_apache Cantidad Nan: 70868 Cantidad de Unicos: 705
# 38 pao2_apache Cantidad Nan: 70868 Cantidad de Unicos: 2004
# 39 ph_apache Cantidad Nan: 70868 Cantidad de Unicos: 556
# 40 resprate_apache Cantidad Nan: 1234 Cantidad de Unicos: 75
# 41 sodium_apache Cantidad Nan: 18600 Cantidad de Unicos: 120
# 42 temp_apache Cantidad Nan: 4108 Cantidad de Unicos: 192
# 43 urineoutput_apache Cantidad Nan: 48998 Cantidad de Unicos: 24773
# 44 ventilated_apache Cantidad Nan: 715 Cantidad de Unicos: 3
# 45 wbc_apache Cantidad Nan: 22012 Cantidad de Unicos: 3076
# 46 d1_diasbp_invasive_max Cantidad Nan: 67984 Cantidad de Unicos: 146
# 47 d1_diasbp_invasive_min Cantidad Nan: 67984 Cantidad de Unicos: 86
# 48 d1_diasbp_max Cantidad Nan: 165 Cantidad de Unicos: 121
# 49 d1_diasbp_min Cantidad Nan: 165 Cantidad de Unicos: 79
# 50 d1_diasbp_noninvasive_max Cantidad Nan: 1040 Cantidad de Unicos: 121
# 51 d1_diasbp_noninvasive_min Cantidad Nan: 1040 Cantidad de Unicos: 79
# 52 d1_heartrate_max Cantidad Nan: 145 Cantidad de Unicos: 121
# 53 d1_heartrate_min Cantidad Nan: 145 Cantidad de Unicos: 155
# 54 d1_mbp_invasive_max Cantidad Nan: 67777 Cantidad de Unicos: 286
# 55 d1_mbp_invasive_min Cantidad Nan: 67777 Cantidad de Unicos: 119
# 56 d1_mbp_max Cantidad Nan: 220 Cantidad de Unicos: 126
# 57 d1_mbp_min Cantidad Nan: 220 Cantidad de Unicos: 92
# 58 d1_mbp_noninvasive_max Cantidad Nan: 1479 Cantidad de Unicos: 123
# 59 d1_mbp_noninvasive_min Cantidad Nan: 1479 Cantidad de Unicos: 92
# 60 d1_resprate_max Cantidad Nan: 385 Cantidad de Unicos: 80
# 61 d1_resprate_min Cantidad Nan: 385 Cantidad de Unicos: 56
# 62 d1_spo2_max Cantidad Nan: 333 Cantidad de Unicos: 44
# 63 d1_spo2_min Cantidad Nan: 333 Cantidad de Unicos: 102
# 64 d1_sysbp_invasive_max Cantidad Nan: 67959 Cantidad de Unicos: 226
# 65 d1_sysbp_invasive_min Cantidad Nan: 67959 Cantidad de Unicos: 164
# 66 d1_sysbp_max Cantidad Nan: 159 Cantidad de Unicos: 144
# 67 d1_sysbp_min Cantidad Nan: 159 Cantidad de Unicos: 121
# 68 d1_sysbp_noninvasive_max Cantidad Nan: 1027 Cantidad de Unicos: 144
# 69 d1_sysbp_noninvasive_min Cantidad Nan: 1027 Cantidad de Unicos: 121
# 70 d1_temp_max Cantidad Nan: 2324 Cantidad de Unicos: 187
# 71 d1_temp_min Cantidad Nan: 2324 Cantidad de Unicos: 210
# 72 h1_diasbp_invasive_max Cantidad Nan: 74928 Cantidad de Unicos: 104
# 73 h1_diasbp_invasive_min Cantidad Nan: 74928 Cantidad de Unicos: 87
# 74 h1_diasbp_max Cantidad Nan: 3619 Cantidad de Unicos: 108
# 75 h1_diasbp_min Cantidad Nan: 3619 Cantidad de Unicos: 93
# 76 h1_diasbp_noninvasive_max Cantidad Nan: 7350 Cantidad de Unicos: 109
# 77 h1_diasbp_noninvasive_min Cantidad Nan: 7350 Cantidad de Unicos: 94
# 78 h1_heartrate_max Cantidad Nan: 2790 Cantidad de Unicos: 120
# 79 h1_heartrate_min Cantidad Nan: 2790 Cantidad de Unicos: 110
# 80 h1_mbp_invasive_max Cantidad Nan: 74844 Cantidad de Unicos: 248
# 81 h1_mbp_invasive_min Cantidad Nan: 74844 Cantidad de Unicos: 134
# 82 h1_mbp_max Cantidad Nan: 4639 Cantidad de Unicos: 118
# 83 h1_mbp_min Cantidad Nan: 4639 Cantidad de Unicos: 108
# 84 h1_mbp_noninvasive_max Cantidad Nan: 9084 Cantidad de Unicos: 116
# 85 h1_mbp_noninvasive_min Cantidad Nan: 9084 Cantidad de Unicos: 108
# 86 h1_resprate_max Cantidad Nan: 4357 Cantidad de Unicos: 51
# 87 h1_resprate_min Cantidad Nan: 4357 Cantidad de Unicos: 92
# 88 h1_spo2_max Cantidad Nan: 4185 Cantidad de Unicos: 73
# 89 h1_spo2_min Cantidad Nan: 4185 Cantidad de Unicos: 101
# 90 h1_sysbp_invasive_max Cantidad Nan: 74915 Cantidad de Unicos: 182
# 91 h1_sysbp_invasive_min Cantidad Nan: 74915 Cantidad de Unicos: 169
# 92 h1_sysbp_max Cantidad Nan: 3611 Cantidad de Unicos: 150
# 93 h1_sysbp_min Cantidad Nan: 3611 Cantidad de Unicos: 143
# 94 h1_sysbp_noninvasive_max Cantidad Nan: 7341 Cantidad de Unicos: 150
# 95 h1_sysbp_noninvasive_min Cantidad Nan: 7341 Cantidad de Unicos: 144
# 96 h1_temp_max Cantidad Nan: 21732 Cantidad de Unicos: 295
# 97 h1_temp_min Cantidad Nan: 21732 Cantidad de Unicos: 304
# 98 d1_albumin_max Cantidad Nan: 49096 Cantidad de Unicos: 36
# 99 d1_albumin_min Cantidad Nan: 49096 Cantidad de Unicos: 36
# 176 aids Cantidad Nan: 715 Cantidad de Unicos: 3
# 177 cirrhosis Cantidad Nan: 715 Cantidad de Unicos: 3
# 178 diabetes_mellitus Cantidad Nan: 715 Cantidad de Unicos: 3
# 179 hepatic_failure Cantidad Nan: 715 Cantidad de Unicos: 3
# 180 immunosuppression Cantidad Nan: 715 Cantidad de Unicos: 3
# 181 leukemia Cantidad Nan: 715 Cantidad de Unicos: 3
# 182 lymphoma Cantidad Nan: 715 Cantidad de Unicos: 3
# 183 solid_tumor_with_metastasis Cantidad Nan: 715 Cantidad de Unicos: 3
# 184 apache_3j_bodysystem Cantidad Nan: 1662 Cantidad de Unicos: 12
# 185 apache_2_bodysystem Cantidad Nan: 1662 Cantidad de Unicos: 11
#
# Existen mucho valores nulos

# %%
mostrasColumnasConNulos( df_test_unlabeled )
print("\nExisten mucho valores nulos")
# Out:
# 3 hospital_death Cantidad Nan: 39308 Cantidad de Unicos: 1
# 4 age Cantidad Nan: 1654 Cantidad de Unicos: 75
# 5 bmi Cantidad Nan: 1086 Cantidad de Unicos: 19328
# 7 ethnicity Cantidad Nan: 171 Cantidad de Unicos: 7
# 8 gender Cantidad Nan: 15 Cantidad de Unicos: 3
# 9 height Cantidad Nan: 750 Cantidad de Unicos: 319
# 10 hospital_admit_source Cantidad Nan: 11948 Cantidad de Unicos: 15
# 11 icu_admit_source Cantidad Nan: 115 Cantidad de Unicos: 6
# 17 weight Cantidad Nan: 764 Cantidad de Unicos: 1912
# 18 albumin_apache Cantidad Nan: 24650 Cantidad de Unicos: 37
# 19 apache_2_diagnosis Cantidad Nan: 896 Cantidad de Unicos: 45
# 20 apache_3j_diagnosis Cantidad Nan: 637 Cantidad de Unicos: 384
# 22 arf_apache Cantidad Nan: 179 Cantidad de Unicos: 3
# 23 bilirubin_apache Cantidad Nan: 25292 Cantidad de Unicos: 491
# 24 bun_apache Cantidad Nan: 7016 Cantidad de Unicos: 125
# 25 creatinine_apache Cantidad Nan: 6896 Cantidad de Unicos: 970
# 26 fio2_apache Cantidad Nan: 29718 Cantidad de Unicos: 60
# 27 gcs_eyes_apache Cantidad Nan: 1163 Cantidad de Unicos: 5
# 28 gcs_motor_apache Cantidad Nan: 1163 Cantidad de Unicos: 7
# 29 gcs_unable_apache Cantidad Nan: 546 Cantidad de Unicos: 3
# 30 gcs_verbal_apache Cantidad Nan: 1163 Cantidad de Unicos: 6
# 31 glucose_apache Cantidad Nan: 4530 Cantidad de Unicos: 546
# 32 heart_rate_apache Cantidad Nan: 306 Cantidad de Unicos: 149
# 33 hematocrit_apache Cantidad Nan: 7747 Cantidad de Unicos: 354
# 34 intubated_apache Cantidad Nan: 179 Cantidad de Unicos: 3
# 35 map_apache Cantidad Nan: 301 Cantidad de Unicos: 171
# 36 paco2_apache Cantidad Nan: 29718 Cantidad de Unicos: 606
# 37 paco2_for_ph_apache Cantidad Nan: 29718 Cantidad de Unicos: 606
# 38 pao2_apache Cantidad Nan: 29718 Cantidad de Unicos: 598
# 154 h1_sodium_max Cantidad Nan: 29869 Cantidad de Unicos: 45
# 155 h1_sodium_min Cantidad Nan: 29869 Cantidad de Unicos: 45
# 156 h1_wbc_max Cantidad Nan: 30769 Cantidad de Unicos: 562
# 157 h1_wbc_min Cantidad Nan: 30769 Cantidad de Unicos: 561
# 158 d1_arterial_pco2_max Cantidad Nan: 25775 Cantidad de Unicos: 711
# 159 d1_arterial_pco2_min Cantidad Nan: 25775 Cantidad de Unicos: 600
# 160 d1_arterial_ph_max Cantidad Nan: 25271 Cantidad de Unicos: 480
# 161 d1_arterial_ph_min Cantidad Nan: 25271 Cantidad de Unicos: 564
# 162 d1_arterial_po2_max Cantidad Nan: 25333 Cantidad de Unicos: 967
# 163 d1_arterial_po2_min Cantidad Nan: 25333 Cantidad de Unicos: 796
# 164 d1_pao2fio2ratio_max Cantidad Nan: 27975 Cantidad de Unicos: 1982
# 165 d1_pao2fio2ratio_min Cantidad Nan: 27975 Cantidad de Unicos: 1755
# 166 h1_arterial_pco2_max Cantidad Nan: 32463 Cantidad de Unicos: 610
# 167 h1_arterial_pco2_min Cantidad Nan: 32463 Cantidad de Unicos: 601
# 168 h1_arterial_ph_max Cantidad Nan: 32181 Cantidad de Unicos: 488
# 169 h1_arterial_ph_min Cantidad Nan: 32181 Cantidad de Unicos: 501
# 170 h1_arterial_po2_max Cantidad Nan: 32256 Cantidad de Unicos: 720
# 171 h1_arterial_po2_min Cantidad Nan: 32256 Cantidad de Unicos: 714
# 172 h1_pao2fio2ratio_max Cantidad Nan: 33986 Cantidad de Unicos: 1331
# 173 h1_pao2fio2ratio_min Cantidad Nan: 33986 Cantidad de Unicos: 1317
# 174 apache_4a_hospital_death_prob Cantidad Nan: 5178 Cantidad de Unicos: 102
# 175 apache_4a_icu_death_prob Cantidad Nan: 5178 Cantidad de Unicos: 100
# 176 aids Cantidad Nan: 179 Cantidad de Unicos: 3
# 177 cirrhosis Cantidad Nan: 179 Cantidad de Unicos: 3
# 178 diabetes_mellitus Cantidad Nan: 179 Cantidad de Unicos: 3
# 179 hepatic_failure Cantidad Nan: 179 Cantidad de Unicos: 3
# 180 immunosuppression Cantidad Nan: 179 Cantidad de Unicos: 3
# 181 leukemia Cantidad Nan: 179 Cantidad de Unicos: 3
# 182 lymphoma Cantidad Nan: 179 Cantidad de Unicos: 3
# 183 solid_tumor_with_metastasis Cantidad Nan: 179 Cantidad de Unicos: 3
# 184 apache_3j_bodysystem Cantidad Nan: 896 Cantidad de Unicos: 12
# 185 apache_2_bodysystem Cantidad Nan: 896 Cantidad de Unicos: 11
#
# Existen mucho valores nulos

# %% [markdown]
# ## 4. Descartando Variables categoricas

# %%
# columnas_train = [x for x in df_train_training_v2.columns if x not in ['encounter_id','patient_id','hospital_death','readmission_status']]
columnas_eliminar = ['encounter_id','patient_id','hospital_death','readmission_status']

# %%
# Elimanando columas que no ingresan en el entrenamiento
# PORQUE QUITAMOS ESTO 'encounter_id','patient_id','hospital_death','readmission_status'
columnas_train = [x for x in df_training_v2.columns if x not in ['encounter_id','patient_id','hospital_death','readmission_status']]
printC("*** Columnas que participan del entrenamiento ***","succ")
print( textwrap.fill( ", ".join(columnas_train) , 140) )

# Seleccionando columnas categoricas
columnas_categoricas = []
for columna in columnas_train:
    if(df_training_v2[columna].dtypes=='object'):
        columnas_categoricas.append(columna)

printC("\n*** Columnas categorias seleccionadas ***","succ")
print( textwrap.fill( ", ".join(columnas_categoricas) , 140) )
# Out:
# *** Columnas que participan del entrenamiento ***
# hospital_id, age, bmi, elective_surgery, ethnicity, gender, height, hospital_admit_source, icu_admit_source, icu_id, icu_stay_type,
# icu_type, pre_icu_los_days, weight, albumin_apache, apache_2_diagnosis, apache_3j_diagnosis, apache_post_operative, arf_apache,
# bilirubin_apache, bun_apache, creatinine_apache, fio2_apache, gcs_eyes_apache, gcs_motor_apache, gcs_unable_apache, gcs_verbal_apache,
# glucose_apache, heart_rate_apache, hematocrit_apache, intubated_apache, map_apache, paco2_apache, paco2_for_ph_apache, pao2_apache,
# ph_apache, resprate_apache, sodium_apache, temp_apache, urineoutput_apache, ventilated_apache, wbc_apache, d1_diasbp_invasive_max,
# d1_diasbp_invasive_min, d1_diasbp_max, d1_diasbp_min, d1_diasbp_noninvasive_max, d1_diasbp_noninvasive_min, d1_heartrate_max,
# d1_heartrate_min, d1_mbp_invasive_max, d1_mbp_invasive_min, d1_mbp_max, d1_mbp_min, d1_mbp_noninvasive_max, d1_mbp_noninvasive_min,
# d1_resprate_max, d1_resprate_min, d1_spo2_max, d1_spo2_min, d1_sysbp_invasive_max, d1_sysbp_invasive_min, d1_sysbp_max, d1_sysbp_min,
# d1_sysbp_noninvasive_max, d1_sysbp_noninvasive_min, d1_temp_max, d1_temp_min, h1_diasbp_invasive_max, h1_diasbp_invasive_min, h1_diasbp_max,
# h1_diasbp_min, h1_diasbp_noninvasive_max, h1_diasbp_noninvasive_min, h1_heartrate_max, h1_heartrate_min, h1_mbp_invasive_max,
# h1_mbp_invasive_min, h1_mbp_max, h1_mbp_min, h1_mbp_noninvasive_max, h1_mbp_noninvasive_min, h1_resprate_max, h1_resprate_min, h1_spo2_max,
# h1_spo2_min, h1_sysbp_invasive_max, h1_sysbp_invasive_min, h1_sysbp_max, h1_sysbp_min, h1_sysbp_noninvasive_max, h1_sysbp_noninvasive_min,
# h1_temp_max, h1_temp_min, d1_albumin_max, d1_albumin_min, d1_bilirubin_max, d1_bilirubin_min, d1_bun_max, d1_bun_min, d1_calcium_max,
# d1_calcium_min, d1_creatinine_max, d1_creatinine_min, d1_glucose_max, d1_glucose_min, d1_hco3_max, d1_hco3_min, d1_hemaglobin_max,
# d1_hemaglobin_min, d1_hematocrit_max, d1_hematocrit_min, d1_inr_max, d1_inr_min, d1_lactate_max, d1_lactate_min, d1_platelets_max,
# d1_platelets_min, d1_potassium_max, d1_potassium_min, d1_sodium_max, d1_sodium_min, d1_wbc_max, d1_wbc_min, h1_albumin_max, h1_albumin_min,
# h1_bilirubin_max, h1_bilirubin_min, h1_bun_max, h1_bun_min, h1_calcium_max, h1_calcium_min, h1_creatinine_max, h1_creatinine_min,
# h1_glucose_max, h1_glucose_min, h1_hco3_max, h1_hco3_min, h1_hemaglobin_max, h1_hemaglobin_min, h1_hematocrit_max, h1_hematocrit_min,
# h1_inr_max, h1_inr_min, h1_lactate_max, h1_lactate_min, h1_platelets_max, h1_platelets_min, h1_potassium_max, h1_potassium_min,
# h1_sodium_max, h1_sodium_min, h1_wbc_max, h1_wbc_min, d1_arterial_pco2_max, d1_arterial_pco2_min, d1_arterial_ph_max, d1_arterial_ph_min,
# d1_arterial_po2_max, d1_arterial_po2_min, d1_pao2fio2ratio_max, d1_pao2fio2ratio_min, h1_arterial_pco2_max, h1_arterial_pco2_min,
# h1_arterial_ph_max, h1_arterial_ph_min, h1_arterial_po2_max, h1_arterial_po2_min, h1_pao2fio2ratio_max, h1_pao2fio2ratio_min,
# apache_4a_hospital_death_prob, apache_4a_icu_death_prob, aids, cirrhosis, diabetes_mellitus, hepatic_failure, immunosuppression, leukemia,
# lymphoma, solid_tumor_with_metastasis, apache_3j_bodysystem, apache_2_bodysystem
#
# *** Columnas categorias seleccionadas ***
# ethnicity, gender, hospital_admit_source, icu_admit_source, icu_stay_type, icu_type, apache_3j_bodysystem, apache_2_bodysystem

# %%
# Unimos los datos categoricos de Entrenamiento y Prueba en uno solo
df_dataAllCategoricos = pd.concat([df_training_v2[columnas_categoricas], df_test_unlabeled[columnas_categoricas]])
printC("Nuevo dataframe: Unimos los datos categoricos de Entrenamiento y Prueba en uno solo", "succ")
display( df_dataAllCategoricos.shape )
display( df_dataAllCategoricos.head() )
# Out:
# Nuevo dataframe: Unimos los datos categoricos de Entrenamiento y Prueba en uno solo
# (131021, 8)
#    ethnicity gender  ... apache_3j_bodysystem apache_2_bodysystem
# 0  Caucasian      M  ...               Sepsis      Cardiovascular
# 1  Caucasian      F  ...          Respiratory         Respiratory
# 2  Caucasian      F  ...            Metabolic           Metabolic
# 3  Caucasian      F  ...       Cardiovascular      Cardiovascular
# 4  Caucasian      M  ...               Trauma              Trauma
#
# [5 rows x 8 columns]

# %%
# Estableciendo valores numericos a columnas categoricas
l = etiquetar_columnas(df_dataAllCategoricos, columnas_categoricas)

printC("*** Columnas Categoricas de datos de Entrenamiento ***", "succ")
display( df_training_v2[columnas_categoricas].head() )

transformar_etiquetas( df_training_v2, l, columnas_categoricas)
printC("\n*** Columnas Categoricas de datos de Entrenamiento con valores numericos ***", "succ")
display( df_training_v2[columnas_categoricas].head() )

transformar_etiquetas( df_test_unlabeled,l,columnas_categoricas )
printC("\n*** Columnas Categoricas de datos de Prueba con valores numericos ***", "succ")
display( df_test_unlabeled[columnas_categoricas].head() )
# Out:
# *** Columnas Categoricas de datos de Entrenamiento ***
#    ethnicity gender  ... apache_3j_bodysystem apache_2_bodysystem
# 0  Caucasian      M  ...               Sepsis      Cardiovascular
# 1  Caucasian      F  ...          Respiratory         Respiratory
# 2  Caucasian      F  ...            Metabolic           Metabolic
# 3  Caucasian      F  ...       Cardiovascular      Cardiovascular
# 4  Caucasian      M  ...               Trauma              Trauma
#
# [5 rows x 8 columns]
# *** Columnas Categoricas de datos de Entrenamiento con valores numericos ***
#   ethnicity gender  ... apache_3j_bodysystem apache_2_bodysystem
# 0         2      1  ...                    9                   0
# 1         2      0  ...                    8                   6
# 2         2      0  ...                    5                   3
# 3         2      0  ...                    0                   0
# 4         2      1  ...                   10                   7
#
# [5 rows x 8 columns]
# *** Columnas Categoricas de datos de Prueba con valores numericos ***
#   ethnicity gender  ... apache_3j_bodysystem apache_2_bodysystem
# 0         2      1  ...                    7                   4
# 1         2      0  ...                    7                   4
# 2         0      1  ...                    0                   0
# 3         2      1  ...                    8                   6
# 4         2      1  ...                    7                   4
#
# [5 rows x 8 columns]

# %%
# tranformar los valores de las variables categoricas a float
for df in [df_training_v2, df_test_unlabeled]:
    for columna in columnas_categoricas:
        df[columna] = df[columna].astype(float)

printC("\n*** Columnas Categoricas de datos de Entrenamiento con valores numericos (float) ***", "succ")
display( df_training_v2[columnas_categoricas].head() )
printC("\n*** Columnas Categoricas de datos de Prueba con valores numericos (float) ***", "succ")
display( df_test_unlabeled[columnas_categoricas].head() )
# Out:
# *** Columnas Categoricas de datos de Entrenamiento con valores numericos (float) ***
#    ethnicity  gender  ...  apache_3j_bodysystem  apache_2_bodysystem
# 0        2.0     1.0  ...                   9.0                  0.0
# 1        2.0     0.0  ...                   8.0                  6.0
# 2        2.0     0.0  ...                   5.0                  3.0
# 3        2.0     0.0  ...                   0.0                  0.0
# 4        2.0     1.0  ...                  10.0                  7.0
#
# [5 rows x 8 columns]
# *** Columnas Categoricas de datos de Prueba con valores numericos (float) ***
#    ethnicity  gender  ...  apache_3j_bodysystem  apache_2_bodysystem
# 0        2.0     1.0  ...                   7.0                  4.0
# 1        2.0     0.0  ...                   7.0                  4.0
# 2        0.0     1.0  ...                   0.0                  0.0
# 3        2.0     1.0  ...                   8.0                  6.0
# 4        2.0     1.0  ...                   7.0                  4.0
#
# [5 rows x 8 columns]

# %%
printC("\n*** Datos Entrenamiento ***", "succ")
display( df_training_v2.head() )
printC("\n*** Datos de Prueba ***", "succ")
display( df_test_unlabeled.head() )
# Out:
# *** Datos Entrenamiento ***
#    encounter_id  patient_id  ...  apache_3j_bodysystem  apache_2_bodysystem
# 0         66154       25312  ...                   9.0                  0.0
# 1        114252       59342  ...                   8.0                  6.0
# 2        119783       50777  ...                   5.0                  3.0
# 3         79267       46918  ...                   0.0                  0.0
# 4         92056       34377  ...                  10.0                  7.0
#
# [5 rows x 186 columns]
# *** Datos de Prueba ***
#    encounter_id  patient_id  ...  apache_3j_bodysystem  apache_2_bodysystem
# 0             2      127112  ...                   7.0                  4.0
# 1             5      130737  ...                   7.0                  4.0
# 2             7      101458  ...                   0.0                  0.0
# 3             8       48067  ...                   8.0                  6.0
# 4            10       25865  ...                   7.0                  4.0
#
# [5 rows x 186 columns]

# %%
#print("Seleccionando variables categoricas de los datos de entrenamiento")
#categorical_df_training_v2 = df_training_v2.select_dtypes(include='object')
#display( categorical_df_training_v2.head() )
#categorical_df_training_v2.info()

# %%
#print("Seleccionando variables categoricas de los datos de prueba")
#categorical_df_test_unlabeled = df_test_unlabeled.select_dtypes(include='object')
#display( categorical_df_test_unlabeled.head() )
#categorical_df_test_unlabeled.info()

# %% [markdown]
# ## 5. Separacion de datos para entrenamiento y Prueba

# %%
# DATOS DE ENTRENAMIENTO
# hacemos una copia de los datos de entrenamiento
df_train = df_training_v2.copy()

# obtenemos la variable dependiente 
df_Y_train = df_train['hospital_death']

# Eliminamos aquellas caracteristicas que no son numericas o tengan valores unicos
#columnasUnicosValores = ['hospital_death','encounter_id','hospital_id','patient_id','icu_id','readmission_status','ethnicity']
columnasUnicosValores = ['hospital_death','encounter_id','patient_id','readmission_status']
df_X_train = df_train.drop(columnasUnicosValores, axis=1).select_dtypes(exclude=['object'])

# Dividimos los tados en entrenamiento y pruebas
X_train, X_train_test, Y_train, Y_train_test = train_test_split(df_X_train, df_Y_train, train_size=0.8, test_size=0.2, random_state=0)

# Observamos como fueron divididos los datos
print("Cantidad de datos para entrenamiento")
display( X_train.shape )
print("Cantidad de datos para pruebas")
display( X_train_test.shape )
# Out:
# Cantidad de datos para entrenamiento
# (73370, 182)
# Cantidad de datos para pruebas
# (18343, 182)

# %%
# DATOS DE ENTRENAMIENTO
# Usamos Imputer para el manejo de datos faltantes
simpleImputer = SimpleImputer()
imputado_X_train = pd.DataFrame(simpleImputer.fit_transform(X_train))
imputado_X_train_test = pd.DataFrame(simpleImputer.transform(X_train_test))

# Imputation removed column names; put them back
imputado_X_train.columns = X_train.columns
imputado_X_train_test.columns = X_train_test.columns

# %%
# DATOS DE PRUEBA
# hacemos una copia de los datos de prueba
df_test = df_test_unlabeled.copy()

# obtenemos la variable dependiente 
df_Y_test = df_test['hospital_death']

# Eliminamos aquellas caracteristicas que no son numericas o tengan valores unicos
#columnasUnicosValores = ['hospital_death','encounter_id','hospital_id','patient_id','icu_id','readmission_status','ethnicity']
columnasUnicosValores = ['hospital_death','encounter_id','patient_id','readmission_status']
df_X_test = df_test.drop(columnasUnicosValores, axis=1).select_dtypes(exclude=['object'])

# datos de prueba separados
display( df_X_test.shape )
df_X_test.head()
# Out:
# (39308, 182)
#    hospital_id   age  ...  apache_3j_bodysystem  apache_2_bodysystem
# 0            7  56.0  ...                   7.0                  4.0
# 1          178   NaN  ...                   7.0                  4.0
# 2           86  66.0  ...                   0.0                  0.0
# 3          163  64.0  ...                   8.0                  6.0
# 4           59  56.0  ...                   7.0                  4.0
#
# [5 rows x 182 columns]

# %%
# Imputation
simpleImputer = SimpleImputer()
# Usamos Imputer para el manejo de datos faltantes
imputado_X_test = pd.DataFrame(simpleImputer. fit_transform(df_X_test))

# Imputation removed column names; put them back
imputado_X_test.columns = df_X_test.columns

# %% [markdown]
# ## 6. Implementamos modelos de Machine Learning

# %%
def evaluarModeloScore(model, X_train, X_test, Y_train, Y_test):
    model.fit(X_train,Y_train)    
    accuracy=model.score(X_test,Y_test)

    print("Modelo: ",model)
    print("Accuracy: ",accuracy)
    preds = model.predict(X_test)
    return model, mean_absolute_error(Y_test, preds)

# %%
# Modelo Arbol de Decisiones
start = time.time()
modelDecisionTreeRegressor = DecisionTreeRegressor(random_state=1)
modelDecisionTreeRegressor, score = evaluarModeloScore( modelDecisionTreeRegressor, imputado_X_train, imputado_X_train_test, Y_train, Y_train_test )
print('MAE:', score)
end = time.time()
print(end - start)
#Modelo:  DecisionTreeRegressor(random_state=1)
#Accuracy:  -0.4386583007979634
#MAE: 0.11911900997655782
# Out:
# Modelo:  DecisionTreeRegressor(random_state=1)
# Accuracy:  -0.4386583007979634
# MAE: 0.11911900997655782
# 16.157872676849365

# %%
# Realizamos la prediccion para los datos de prueba
prediccion = modelDecisionTreeRegressor.predict(imputado_X_test)

# Guardamos la prediccion de los datos
resultado= pd.DataFrame({'encounter_id': df_test_unlabeled.encounter_id,
                       'hospital_death': prediccion},dtype=np.int32)
 
resultado.to_csv('modelDecisionTreeRegressor.csv', index=False)
resultado.head()
# Out:
#    encounter_id  hospital_death
# 0             2               0
# 1             5               0
# 2             7               0
# 3             8               0
# 4            10               1

# %%
start = time.time()
modelXGBRegressor = XGBRegressor(n_estimators=1000, learning_rate=0.05, n_jobs=4)
modelXGBRegressor, score = evaluarModeloScore( modelXGBRegressor, imputado_X_train, imputado_X_train_test, Y_train, Y_train_test )
print('MAE:', score)
end = time.time()
print(end - start)
#Modelo:  XGBRegressor(learning_rate=0.05, n_estimators=1000, n_jobs=4)
#Accuracy:  0.3384772537609704
#MAE: 0.11527414228445258
##-----------------------------
##X_train = imputed_X_train
##X_valid = imputed_X_valid
#
##xgb_model = XGBRegressor(n_estimators=1000, learning_rate=0.05, n_jobs=4)
#
##xgb_model.fit(X_train, y_train, 
##             early_stopping_rounds=5, 
##             eval_set=[(X_valid, y_valid)], 
##             verbose=False)
#
##predictions = xgb_model.predict(X_valid)
#
##print("Mean Absolute Error: " + str(mean_absolute_error(predictions, y_valid)))
# Out:
# [01:15:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Modelo:  XGBRegressor(learning_rate=0.05, n_estimators=1000, n_jobs=4)
# Accuracy:  0.3384772537609704
# MAE: 0.11527414228445258
# 241.63996839523315

# %%
# Realizamos la prediccion para los datos de prueba
prediccion = modelXGBRegressor.predict(imputado_X_test)

# Guardamos la prediccion de los datos
resultado= pd.DataFrame({'encounter_id': df_test_unlabeled.encounter_id,
                       'hospital_death': prediccion},dtype=np.int32)
 
resultado.to_csv('modelXGBRegressor.csv', index=False)
resultado.head()
# Out:
#    encounter_id  hospital_death
# 0             2       -0.015443
# 1             5        0.006419
# 2             7       -0.023878
# 3             8        0.138021
# 4            10        0.332631

# %%
start = time.time()
modelSVR = SVR()
modelSVR, score = evaluarModeloScore( modelSVR, imputado_X_train, imputado_X_train_test, Y_train, Y_train_test )
print('MAE:', score)
end = time.time()
print(end - start)
##Modelo:  SVR()
##Accuracy:  0.03071240426525712
##MAE: 0.16662195943309246
# Out:
# Modelo:  SVR()
# Accuracy:  0.030740364800075026
# MAE: 0.1665151531570379
# 2224.584941625595

# %%
# Realizamos la prediccion para los datos de prueba
prediccion = modelSVR.predict(imputado_X_test)

# Guardamos la prediccion de los datos
resultado= pd.DataFrame({'encounter_id': df_test_unlabeled.encounter_id,
                       'hospital_death': prediccion},dtype=np.int32)
 
resultado.to_csv('modelSVR.csv', index=False)
resultado.head()
# Out:
#    encounter_id  hospital_death
# 0             2        0.082762
# 1             5        0.090840
# 2             7        0.090977
# 3             8        0.091516
# 4            10        0.097223

# %%
start = time.time()
modelLinearModelRidge = linear_model.Ridge(alpha=.5)
modelLinearModelRidge, score = evaluarModeloScore( modelLinearModelRidge, imputado_X_train, imputado_X_train_test, Y_train, Y_train_test )
print('MAE:', score)
end = time.time()
print(end - start)
##Modelo:  Ridge(alpha=0.5)
##Accuracy:  0.25921436267450737
##MAE: 0.13916450251823517
# Out:
# Modelo:  Ridge(alpha=0.5)
# Accuracy:  0.2603602861388249
# MAE: 0.1390769954999846
# 0.27907395362854004

# %%
# Realizamos la prediccion para los datos de prueba
prediccion = modelLinearModelRidge.predict(imputado_X_test)

# Guardamos la prediccion de los datos
resultado= pd.DataFrame({'encounter_id': df_test_unlabeled.encounter_id,
                       'hospital_death': prediccion},dtype=np.int32)
 
resultado.to_csv('modelLinearModelRidge.csv', index=False)
resultado.head()
# Out:
#    encounter_id  hospital_death
# 0             2        0.057840
# 1             5       -0.044399
# 2             7        0.046695
# 3             8        0.165938
# 4            10        0.167931

# %%
start = time.time()
modelLinearModelLassoLars = linear_model.LassoLars(alpha=.1, normalize=False)
modelLinearModelLassoLars, score = evaluarModeloScore( modelLinearModelLassoLars, imputado_X_train, imputado_X_train_test, Y_train, Y_train_test )
print('MAE:', score)
end = time.time()
print(end - start)
##Modelo:  LassoLars(alpha=0.1, normalize=False)
##Accuracy:  0.12966314111211286
##MAE: 0.15174781441453442
# Out:
# Modelo:  LassoLars(alpha=0.1, normalize=False)
# Accuracy:  0.12966314111211252
# MAE: 0.15174781441453447
# 0.21149992942810059

# %%
# Realizamos la prediccion para los datos de prueba
prediccion = modelLinearModelLassoLars.predict(imputado_X_test)

# Guardamos la prediccion de los datos
resultado= pd.DataFrame({'encounter_id': df_test_unlabeled.encounter_id,
                       'hospital_death': prediccion},dtype=np.int32)
 
resultado.to_csv('modelLinearModelLassoLars.csv', index=False)
resultado.head()
# Out:
#    encounter_id  hospital_death
# 0             2        0.081594
# 1             5        0.028829
# 2             7        0.034877
# 3             8        0.168962
# 4            10        0.053014

# %%
start = time.time()
modelLinearModelBR = linear_model.BayesianRidge()
modelLinearModelBR, score = evaluarModeloScore( modelLinearModelBR, imputado_X_train, imputado_X_train_test, Y_train, Y_train_test )
print('MAE:', score)
end = time.time()
print(end - start)
##Modelo:  BayesianRidge()
##Accuracy:  0.2593604329121887
##MAE: 0.13913391675326037
# Out:
# Modelo:  BayesianRidge()
# Accuracy:  0.26043317556061973
# MAE: 0.1390538417501715
# 2.2046213150024414

# %%
# Realizamos la prediccion para los datos de prueba
prediccion = modelLinearModelBR.predict(imputado_X_test)

# Guardamos la prediccion de los datos
resultado= pd.DataFrame({'encounter_id': df_test_unlabeled.encounter_id,
                       'hospital_death': prediccion},dtype=np.int32)
 
resultado.to_csv('modelLinearModelBR.csv', index=False)
resultado.head()
# Out:
#    encounter_id  hospital_death
# 0             2        0.059308
# 1             5       -0.045675
# 2             7        0.051381
# 3             8        0.161763
# 4            10        0.165725

# %%
start = time.time()
modelLinearModelLR = LogisticRegression(C=0.1, penalty="l1", tol=0.01, solver="saga")
modelLinearModelLR, score = evaluarModeloScore( modelLinearModelLR, imputado_X_train, imputado_X_train_test, Y_train, Y_train_test )
print('MAE:', score)
end = time.time()
print(end - start)
# Out:
# Modelo:  LogisticRegression(C=0.1, penalty='l1', solver='saga', tol=0.01)
# Accuracy:  0.9153900670555525
# MAE: 0.08460993294444748
# 13.359800815582275

# %%
# Realizamos la prediccion para los datos de prueba
prediccion = modelLinearModelLR.predict(imputado_X_test)

# Guardamos la prediccion de los datos
resultado= pd.DataFrame({'encounter_id': df_test_unlabeled.encounter_id,
                       'hospital_death': prediccion},dtype=np.int32)
 
resultado.to_csv('modelLinearModelLR.csv', index=False)
resultado.head()
# Out:
#    encounter_id  hospital_death
# 0             2               0
# 1             5               0
# 2             7               0
# 3             8               0
# 4            10               0

# %%
start = time.time()
modelRFR = RandomForestRegressor(max_depth=15)
modelRFR, score = evaluarModeloScore( modelRFR, imputado_X_train, imputado_X_train_test, Y_train, Y_train_test )
print('MAE:', score)
end = time.time()
print(end - start)
# Out:
# Modelo:  RandomForestRegressor(max_depth=15)
# Accuracy:  0.30946348210230934
# MAE: 0.1130038255820975
# 435.6586842536926

# %%
# Realizamos la prediccion para los datos de prueba
prediccion = modelRFR.predict(imputado_X_test)

# Guardamos la prediccion de los datos
resultado= pd.DataFrame({'encounter_id': df_test_unlabeled.encounter_id,
                       'hospital_death': prediccion},dtype=np.int32)
 
resultado.to_csv('modelRFR.csv', index=False)
resultado.head()
# Out:
#    encounter_id  hospital_death
# 0             2        0.051910
# 1             5        0.038609
# 2             7        0.006720
# 3             8        0.127156
# 4            10        0.372541

# %%
start = time.time()
modelRFR = RandomForestRegressor(n_estimators=40, max_depth=15, criterion='mse' )
modelRFR, score = evaluarModeloScore( modelRFR, imputado_X_train, imputado_X_train_test, Y_train, Y_train_test )
print('MAE:', score)
end = time.time()
print(end - start)
#
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py:400: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   FutureWarning,
# Modelo:  RandomForestRegressor(criterion='mse', max_depth=15, n_estimators=40)
# Accuracy:  0.30620744031421687
# MAE: 0.112806828775461
# 174.15852308273315

# %%
# Realizamos la prediccion para los datos de prueba
prediccion = modelRFR.predict(imputado_X_test)

# Guardamos la prediccion de los datos
resultado= pd.DataFrame({'encounter_id': df_test_unlabeled.encounter_id,
                       'hospital_death': prediccion},dtype=np.int32)
 
resultado.to_csv('modelRFR_2.csv', index=False)
resultado.head()
# Out:
#    encounter_id  hospital_death
# 0             2        0.056755
# 1             5        0.065603
# 2             7        0.006569
# 3             8        0.076353
# 4            10        0.328276
